# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA L4

# %%
# !pip install transformers datasets accelerate sentencepiece

# %%
from transformers import PreTrainedTokenizerFast, BartForConditionalGeneration

tokenizer = PreTrainedTokenizerFast.from_pretrained("gogamza/kobart-base-v1")
model = BartForConditionalGeneration.from_pretrained("gogamza/kobart-base-v1")
# Out:
# ...
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/4.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/495M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/259 [00:00<?, ?it/s]

# %%
# !ls
# Out:
#  BUILD_FROM_SOURCE_PACKAGES_LICENCES	   PYTHON_PACKAGES_LICENSES
#  Kobart.ipynb				   THIRD_PARTY_SOURCE_CODE_URLS
#  LINUX_PACKAGES_LICENSES		   setup-jupyter.sh
#  LINUX_PACKAGES_LIST			  'train (1).source'
#  OSSNvidiaDriver_v580.126.16_license.txt  'train (1).target'

# %%
# !mv "train (1).source" train.source
# !mv "train (1).target" train.target

# %%
# !ls
# Out:
# BUILD_FROM_SOURCE_PACKAGES_LICENCES	 PYTHON_PACKAGES_LICENSES
# Kobart.ipynb				 THIRD_PARTY_SOURCE_CODE_URLS
# LINUX_PACKAGES_LICENSES			 setup-jupyter.sh
# LINUX_PACKAGES_LIST			 train.source
# OSSNvidiaDriver_v580.126.16_license.txt  train.target

# %%
with open("train.source", "r", encoding="utf-8") as f:
    gloss = f.read().splitlines()

with open("train.target", "r", encoding="utf-8") as f:
    sentence = f.read().splitlines()

print("Gloss samples:", len(gloss))
print("Sentence samples:", len(sentence))

print("\nExample:")
print("Gloss:", gloss[0])
print("Sentence:", sentence[0])
# Out:
# Gloss samples: 2396
# Sentence samples: 2396
#
# Example:
# Gloss: 집 불
# Sentence: 집에 불이 났어요.

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Loading dataset...
# Traceback (most recent call last):
#   File "/home/ubuntu/train.py", line 57, in <module>
#     valid_dataset = load_parallel_data(VALID_SOURCE, VALID_TARGET)
#   File "/home/ubuntu/train.py", line 42, in load_parallel_data
#     with open(src_path, "r", encoding="utf-8") as f:
#          ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'valid.source'

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Loading dataset...
# Train size: 2156
# Valid size: 240
# config.json: 1.36kB [00:00, 6.68MB/s]
# ...
# tokenizer.json: 682kB [00:00, 145MB/s]
# added_tokens.json: 100%|█████████████████████| 4.00/4.00 [00:00<00:00, 28.6kB/s]
# special_tokens_map.json: 100%|██████████████████| 112/112 [00:00<00:00, 213kB/s]
# model.safetensors: 100%|█████████████████████| 495M/495M [00:06<00:00, 72.7MB/s]
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 4411.29it/s]
# Tokenizing dataset...
# ...
# Map: 100%|███████████████████████████| 240/240 [00:00<00:00, 4149.83 examples/s]
# Traceback (most recent call last):
#   File "/home/ubuntu/train.py", line 143, in <module>
# ...

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Loading dataset...
# Train size: 2156
# Valid size: 240
# ...
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 4451.04it/s]
# Tokenizing dataset...
# ...
# Map: 100%|███████████████████████████| 240/240 [00:00<00:00, 3982.80 examples/s]
# Start training...
# {'loss': '4.794', 'grad_norm': '10.98', 'learning_rate': '4.94e-05', 'epoch': '0.1852'}
# {'loss': '0.3757', 'grad_norm': '1.644', 'learning_rate': '4.878e-05', 'epoch': '0.3704'}
# {'loss': '0.2145', 'grad_norm': '1.708', 'learning_rate': '4.816e-05', 'epoch': '0.5556'}
# {'loss': '0.1691', 'grad_norm': '1.648', 'learning_rate': '4.754e-05', 'epoch': '0.7407'}
# ...

# %%
# !ls outputs/checkpoints/kobart-best
# Out:
# config.json		model.safetensors  tokenizer_config.json
# generation_config.json	tokenizer.json	   training_args.bin

# %%
# !python predict.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Loading model...
# Loading weights: 100%|██████████████████████| 260/260 [00:00<00:00, 4582.22it/s]
# Using device: cuda
# Model loaded successfully.
#
# KoBART Gloss -> Sentence Translator
# Type 'exit' to quit.
#
# Enter gloss:

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Loading dataset...
# Train size: 2156
# Valid size: 240
# ...
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 1376.36it/s]
# Tokenizing dataset...
# ...
# Map: 100%|███████████████████████████| 240/240 [00:00<00:00, 3953.64 examples/s]
# Start training...
# {'loss': '4.58', 'grad_norm': '9.8', 'learning_rate': '4.94e-05', 'epoch': '0.1852'}
# {'loss': '0.2993', 'grad_norm': '1.374', 'learning_rate': '4.878e-05', 'epoch': '0.3704'}
# {'loss': '0.1701', 'grad_norm': '1.76', 'learning_rate': '4.816e-05', 'epoch': '0.5556'}
# {'loss': '0.1389', 'grad_norm': '1.516', 'learning_rate': '4.754e-05', 'epoch': '0.7407'}
# ...

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Loading dataset...
# Train size: 2156
# Valid size: 240
# Loading KoBART model...
# ...
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 4880.60it/s]
# Tokenizing dataset...
# ...
# Map: 100%|███████████████████████████| 240/240 [00:00<00:00, 4885.74 examples/s]
# Start training...
# {'loss': '4.078', 'grad_norm': '20.31', 'learning_rate': '2.946e-05', 'epoch': '0.1852'}
# {'loss': '2.074', 'grad_norm': '19.29', 'learning_rate': '2.89e-05', 'epoch': '0.3704'}
# {'loss': '1.519', 'grad_norm': '16.15', 'learning_rate': '2.834e-05', 'epoch': '0.5556'}
# {'loss': '1.36', 'grad_norm': '13.6', 'learning_rate': '2.779e-05', 'epoch': '0.7407'}
# ...

# %%
python predict.py
# Out:
#   Cell In[3], line 1
#     python predict.py
#            ^
# SyntaxError: invalid syntax

# %%
# !python predict.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Loading model...
# Loading weights: 100%|██████████████████████| 260/260 [00:00<00:00, 4814.21it/s]
# Using device: cuda
# Model loaded successfully.
#
# KoBART Gloss -> Sentence Translator
# Type 'exit' to quit.
#
# Enter gloss:

# %%
# !rm -rf outputs/checkpoints

# %%
# !python train.py

# %%
# !python train.py

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# Loading dataset...
# Train size: 2156
# Valid size: 240
# Loading KoBART tokenizer/model...
# ...
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 1460.97it/s]
# Tokenizing dataset...
# ...
# Map: 100%|███████████████████████████| 240/240 [00:00<00:00, 4806.65 examples/s]
# Start training...
# {'loss': '4.078', 'grad_norm': '20.44', 'learning_rate': '2.891e-05', 'epoch': '0.1852'}
# {'loss': '2.08', 'grad_norm': '19.07', 'learning_rate': '2.78e-05', 'epoch': '0.3704'}
# {'loss': '1.524', 'grad_norm': '16.35', 'learning_rate': '2.669e-05', 'epoch': '0.5556'}
# ...

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# Loading dataset...
# Train size: 2156
# Valid size: 240
# Loading KoBART tokenizer/model...
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 4463.99it/s]
# Tokenizing dataset...
# ...
# Map: 100%|███████████████████████████| 240/240 [00:00<00:00, 4844.12 examples/s]
# Start training...
# {'loss': '4.078', 'grad_norm': '20.44', 'learning_rate': '2.891e-05', 'epoch': '0.1852'}
# {'loss': '2.08', 'grad_norm': '19.07', 'learning_rate': '2.78e-05', 'epoch': '0.3704'}
# {'loss': '1.524', 'grad_norm': '16.35', 'learning_rate': '2.669e-05', 'epoch': '0.5556'}
# ...

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# Loading dataset...
# Train size: 2156
# Valid size: 240
# Loading KoBART tokenizer/model...
# ...
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 4587.17it/s]
# Tokenizing dataset...
# ...
# Map: 100%|███████████████████████████| 240/240 [00:00<00:00, 3833.83 examples/s]
# Start training...
# {'loss': '4.596', 'grad_norm': '10.25', 'learning_rate': '4.87e-05', 'epoch': '0.1852'}
# {'loss': '0.3', 'grad_norm': '1.384', 'learning_rate': '4.738e-05', 'epoch': '0.3704'}
# {'loss': '0.1701', 'grad_norm': '1.815', 'learning_rate': '4.606e-05', 'epoch': '0.5556'}
# ...

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# Loading dataset...
# Train size: 2156
# Valid size: 240
# Loading KoBART tokenizer/model...
# ...
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 4482.92it/s]
# Tokenizing dataset...
# ...
# Map: 100%|███████████████████████████| 240/240 [00:00<00:00, 3811.79 examples/s]
# Start training...
# {'loss': '4.596', 'grad_norm': '10.25', 'learning_rate': '4.87e-05', 'epoch': '0.1852'}
# {'loss': '0.3', 'grad_norm': '1.384', 'learning_rate': '4.738e-05', 'epoch': '0.3704'}
# {'loss': '0.1701', 'grad_norm': '1.815', 'learning_rate': '4.606e-05', 'epoch': '0.5556'}
# ...

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# Loading dataset...
# Train size: 2156
# Valid size: 240
# Loading KoBART tokenizer/model...
# ...
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 4260.48it/s]
# Tokenizing dataset...
# ...
# Map: 100%|███████████████████████████| 240/240 [00:00<00:00, 4792.65 examples/s]
# Start training...
# {'loss': '4.621', 'grad_norm': '24.41', 'learning_rate': '1.955e-05', 'epoch': '0.1852'}
# {'loss': '2.28', 'grad_norm': '20.59', 'learning_rate': '1.908e-05', 'epoch': '0.3704'}
# {'loss': '1.687', 'grad_norm': '19.56', 'learning_rate': '1.862e-05', 'epoch': '0.5556'}
# ...

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# Loading datasets...
# Traceback (most recent call last):
#   File "/home/ubuntu/train.py", line 95, in <module>
#     valid_dataset = load_parallel_data(
#         VALID_SOURCE,
#         VALID_TARGET
#     )
#   File "/home/ubuntu/train.py", line 57, in load_parallel_data
#     with open(src_path, "r", encoding="utf-8") as f:
#          ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'valid.source'

# %%
# !python train.py
# Out:
# /opt/pytorch/lib/python3.13/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Using device: cuda
# Loading datasets...
# Train size: 2396
# Valid size: 318
# Loading KoBART tokenizer/model...
# ...
# Loading weights: 100%|██████████████████████| 259/259 [00:00<00:00, 1309.16it/s]
# Tokenizing datasets...
# ...
# Map: 100%|███████████████████████████| 318/318 [00:00<00:00, 6201.59 examples/s]
#
# Start training...
#
# {'loss': '4.224', 'grad_norm': '24.3', 'learning_rate': '2.902e-05', 'epoch': '0.1667'}
# {'loss': '1.966', 'grad_norm': '18.99', 'learning_rate': '2.802e-05', 'epoch': '0.3333'}
# {'loss': '1.622', 'grad_norm': '14.64', 'learning_rate': '2.702e-05', 'epoch': '0.5'}
# ...

# %%
# !ls
# Out:
# BUILD_FROM_SOURCE_PACKAGES_LICENCES	 check.ipynb	   train.py
# Kobart.ipynb				 evaluate.py	   train.source
# LINUX_PACKAGES_LICENSES			 outputs	   train.target
# LINUX_PACKAGES_LIST			 predict.py	   val.source
# OSSNvidiaDriver_v580.126.16_license.txt  setup-jupyter.sh  val.target
# PYTHON_PACKAGES_LICENSES		 test.source
# THIRD_PARTY_SOURCE_CODE_URLS		 test.target
